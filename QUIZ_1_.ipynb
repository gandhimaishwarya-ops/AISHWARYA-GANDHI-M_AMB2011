# %%
#AISHWARYA GANDHI.M
#AMB2011

# %%
num=[1,2,3,4]
squares=[]
for n in num:
    squares.append(n**2)
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
nums=[1,2,3,4,5]
for n in nums:
  if n>3:
    print(n)
# Out:
# 4
# 5

# %%
nums=[1,2,3,4]
for i in range(len(nums)):
    nums[i]*=2
print(nums)
# Out:
# [2, 4, 6, 8]

# %%
n=-3
if n>=0:
  if n==0:
    print("zero")
  else:
    print("positive")
else:
    print("negative")
# Out:
# negative

# %%
lst=[1,2,3]
for x in lst:
  lst.append(x)
  if len(lst)>4:
    break
print(lst)
# Out:
# [1, 2, 3, 1, 2]

# %%
lst=[1,2,3,4]
for x in lst:
  if x%2==0:
    lst.remove(x)
print(lst)
# Out:
# [1, 3]

# %%
x=5
if x>0:
  if x>10:
    print("large positive")
  else:
    print("small positive")
else:
 print("non positive")
# Out:
# small positive

# %%
a=[1,2,3]
b=a
b.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
for i in range(1,6):
  if i%2==0:
     continue
  print(i)
# Out:
# 1
# 3
# 5

# %%
i=1
while i<=5:
  i+=2
  print(i)
# Out:
# 3
# 5
# 7

# %%
x=15
if x>10:
  print("A")
if x>5:
  print("B")
# Out:
# A
# B

# %%
nums=[1,2,3,4]
for n in nums:
  print(n)
# Out:
# 1
# 2
# 3
# 4

# %%
nums=[10,20,30]
i=0
while i<len(nums):
  print(nums[i])
  i+=1
# Out:
# 10
# 20
# 30

# %%
score=75
if score>=90:
  grade="A"
elif score>=80:
  grade="B"
elif score>=70:
  grade="C"
else:
  grade="F"
print(grade)
# Out:
# C

# %%
nums=[1,2,3,4,5]
i=0
while i<len(nums):
  if nums[i]%2==0:
    nums.pop(i)
  else:
    i+=1
print(nums)
# Out:
# [1, 3, 5]

# %%
x=25
if x>10:
  if x>20:
    print("A")
  else:
    print("B")
else:
  print("C")
# Out:
# A

# %%
nums=[3,6,9,12]
total=0
for n in nums:
  total+=n
print(total)
# Out:
# 30

# %%
nums=[5,10,15]
for n in nums:
  n+=5
print(nums)
# Out:
# [5, 10, 15]
