# %%
#AISHWARYA GANDHI.M
#AMB2011

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(CGPA)
print(len(CGPA))
print(type(CGPA))
print(CGPA.keys())
print(CGPA.values())
# Out:
# {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# 5
# <class 'dict'>
# dict_keys([1, 2, 4, 7, 8])
# dict_values([8.9, 5.6, 6.7, 9.1, 5.3])

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(CGPA[1])
print(CGPA[4])
print(CGPA[7])
print(CGPA[3])
# Out:
# 8.9
# 6.7
# 9.1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2523445841.py in <cell line: 0>()
#       3 print(CGPA[4])
#       4 print(CGPA[7])
# ----> 5 print(CGPA[3])
#
# KeyError: 3

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
for k in CGPA:
  print("CGPA of",k,"is",CGPA[k])
# Out:
# CGPA of 1 is 8.9
# CGPA of 2 is 5.6
# CGPA of 4 is 6.7
# CGPA of 7 is 9.1
# CGPA of 8 is 5.3

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
for k in CGPA:
  print("CGPA of",k,"is \n", CGPA[k])
# Out:
# CGPA of 1 is
#  8.9
# CGPA of 2 is
#  5.6
# CGPA of 4 is
#  6.7
# CGPA of 7 is
#  9.1
# CGPA of 8 is
#  5.3

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary",CGPA)
print("key",CGPA.keys())
print("values",CGPA.values())
# Out:
# Dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# key dict_keys([1, 2, 4, 7, 8])
# values dict_values([8.9, 5.6, 6.7, 9.1, 5.3])

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary",CGPA)
CGPA[3]=8.6
print("\n after adding",CGPA)
CGPA[9]=7.6
print("after adding(9)",CGPA)
# Out:
# Dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
#
#  after adding {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6}
# after adding(9) {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3, 3: 8.6, 9: 7.6}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary",CGPA)
CGPA[4]=9.2
print("\n after updating(4)",CGPA)
CGPA[10]=8.8
print("after adding(10)",CGPA)
# Out:
# Dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
#
#  after updating(4) {1: 8.9, 2: 5.6, 4: 9.2, 7: 9.1, 8: 5.3}
# after adding(10) {1: 8.9, 2: 5.6, 4: 9.2, 7: 9.1, 8: 5.3, 10: 8.8}

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary",CGPA)
del CGPA[1]
print("\n after deleting(4)",CGPA)
del CGPA[8]
print("after deleting(7)",CGPA)
del CGPA
print("after deleting",CGPA)
# Out:
# Dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
#
#  after deleting(4) {2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# after deleting(7) {2: 5.6, 4: 6.7, 7: 9.1}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3030263366.py in <cell line: 0>()
#       6 print("after deleting(7)",CGPA)
#       7 del CGPA
# ----> 8 print("after deleting",CGPA)
#
# NameError: name 'CGPA' is not defined

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("Dictionary",CGPA)
CGPA.clear()
print("\n after deleting",CGPA)
# Out:
# Dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
#
#  after deleting {}

# %% [markdown]
# average CGPA

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
sum=0
for k in CGPA:
  sum=sum+CGPA[k]
print("average",sum/len(CGPA))
print("average",sum//len(CGPA))
# Out:
# average 7.119999999999999
# average 7.0

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictionary",CGPA)
print("sum",sum(CGPA.values()))
print("average",sum(CGPA.values())/len(CGPA))
# Out:
# dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# sum 35.6
# average 7.12

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictionary",CGPA)
print(min(CGPA.values()))
print(max(CGPA.values()))
# Out:
# dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# 5.3
# 9.1

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictionary",CGPA)
print(min(k for k in CGPA))
print(max(k for k in CGPA))
# Out:
# dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# 1
# 8

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
min_key=min(CGPA,key=CGPA.get)
max_key=max(CGPA,key=CGPA.get)
print("min",min_key)
print("max",max_key)
# Out:
# min 8
# max 7

# %% [markdown]
# to get values iin list

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print(CGPA.keys())
print(list(CGPA.keys()))
print()
# Out:
# dict_keys([1, 2, 4, 7, 8])
# [1, 2, 4, 7, 8]

# %% [markdown]
# by using index method find value of minumum value key and maximum value key

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictionary",CGPA)
print("\n min value",min(CGPA.values()))
print("max value",max(CGPA.values()))

      # method 1 to find key for min value

keylist=list(CGPA.keys())
valuelist=list(CGPA.values())
minval=min(CGPA.values())
print("\n value=",minval,"key",keylist[valuelist.index(minval)])
# Out:
# dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
#
#  min value 5.3
# max value 9.1
#
#  value= 5.3 key 8

# %% [markdown]
# 2.14 searching value in dictionary

# %%
CGPA={1:8.9,2:5.6,4:6.7,7:9.1,8:5.3}
print("dictionary",CGPA)
print("is key 2 present",2 in CGPA.keys())
print("is key 9 present",9 in CGPA.keys())
# Out:
# dictionary {1: 8.9, 2: 5.6, 4: 6.7, 7: 9.1, 8: 5.3}
# is key 2 present True
# is key 9 present False

# %% [markdown]
# merging of dictionary
# using update method

# %%
CGPA={1:8.9,2:5.6,4:9.7}
CGPA1={4:6.7,7:9.1,8:5.3}
print("CGPA",CGPA)
print("CGPA1",CGPA1)
CGPA1.update(CGPA)

print("\nCGPA1 after update",CGPA1)
print("\nCGPA after update",CGPA)
# Out:
# CGPA {1: 8.9, 2: 5.6, 4: 9.7}
# CGPA1 {4: 6.7, 7: 9.1, 8: 5.3}
#
# CGPA1 after update {4: 9.7, 7: 9.1, 8: 5.3, 1: 8.9, 2: 5.6}
#
# CGPA after update {1: 8.9, 2: 5.6, 4: 9.7}

# %% [markdown]
# ASSINGMENT
# 1.create a dictionary named cars
#     key=brand,model,year
#     values=ford,mustang,1964
# 2.print dictionary elements
# 3.add one more element:red
# 4.print keys,values,items
# 5.check whether model is present in cars dictionary

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary",cars)
# Out:
# dictionary {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary",cars)
cars["color"]="red"
print("dictionary",cars)
# Out:
# dictionary {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# dictionary {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'color': 'red'}

# %%
cars={"brand":"ford","model":"mustang","year":1964}
cars1={"color":"red"}
cars.update(cars1)
print("dictionary",cars)
# Out:
# dictionary {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'color': 'red'}

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary",cars)
print("keys",cars.keys())
print("values",cars.values())
print("items",cars.items())
# Out:
# dictionary {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# keys dict_keys(['brand', 'model', 'year'])
# values dict_values(['ford', 'mustang', 1964])
# items dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary",cars)
print("is model present",cars.keys())
# Out:
# dictionary {'brand': 'ford', 'model': 'mustang', 'year': 1964}
# is model present dict_keys(['brand', 'model', 'year'])

# %% [markdown]
# create a dictionary from 2 list     keys=[movie,hero,release year]
# values[kantara,Rishab,2022]

# %%
keylist=["movie","hero","release year"]
valuelist=["kantara","Rishab","2022"]
movie=dict(zip(keylist,valuelist))
print(movie)
# Out:
# {'movie': 'kantara', 'hero': 'Rishab', 'release year': '2022'}

# %%
keylist=["movie","hero","release year"]
valuelist=["kantara","Rishab","2022"]
mdict={}
for i in range(len(keylist)):
  movie[keylist[i]]=valuelist[i]
print(movie)
# Out:
# {'movie': 'kantara', 'hero': 'Rishab', 'release year': '2022'}

# %% [markdown]
# copying and equal

# %%
#method 1 :using '='operator

dict1={'Name':'Jhon',10:[2,4,3]}
dict2=dict1
print(dict1)
print(dict2)
print()
print("after doing change")
print()
dict1.popitem()
print(dict1)
print(dict2)
print("change in dict1 will note reflect in dict2")
# Out:
# {'Name': 'Jhon', 10: [2, 4, 3]}
# {'Name': 'Jhon', 10: [2, 4, 3]}
#
# after doing change
#
# {'Name': 'Jhon'}
# {'Name': 'Jhon'}
# change in dict1 will note reflect in dict2

# %% [markdown]
# rice:120,wheat:85,maize:60
# a)print the dictionary

# %%
crop_list=["rice","wheat","maize"]
yield_list=[120,85,60]
crop_yield=dict(zip(crop_list,yield_list))
print(crop_yield)
# Out:
# {'rice': 120, 'wheat': 85, 'maize': 60}

# %% [markdown]
# b)find the number of crops cultivated by the farmer

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print(len(crop_yield))
# Out:
# 3

# %% [markdown]
# c.display the yield of wheat(by get and without get method)

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print(crop_yield["wheat"])
print("yield of wheat is",crop_yield["wheat"])
print("yield of wheat is",crop_yield.get("wheat"))
# Out:
# 85
# yield of wheat is 85
# yield of wheat is 85

# %% [markdown]
# d.add a crop pulses with yield 45,print complete dictionary

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
crop_yield["pulses"]=45
print("after adding",("pulses"),crop_yield)
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# after adding pulses {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %% [markdown]
# e)update the yield of rice to 130

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
crop_yield["rice"]=130
print("after updating",("rice"),crop_yield)
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# after updating rice {'rice': 130, 'wheat': 85, 'maize': 60}

# %% [markdown]
# f)display all crop names cultivated by farmers

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
print("crop_list",crop_yield.keys())
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# crop_list dict_keys(['rice', 'wheat', 'maize'])

# %% [markdown]
# g)display all crop yields

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
print("yield_list",crop_yield.values())
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# yield_list dict_values([120, 85, 60])

# %% [markdown]
# h)check whether sugarcane is cultivated by farmer(use in membership operator)

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
print("is key sugarcane present","sugarcane" in crop_yield.keys())
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# is key sugarcane present False

# %% [markdown]
# g)increase the yield of wheat by 10

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
crop_yield["wheat"]=crop_yield["wheat"]+10
print("after updating",("wheat"),crop_yield)
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# after updating wheat {'rice': 120, 'wheat': 95, 'maize': 60}

# %% [markdown]
# h)calculate total yield of all crops

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
sum=0
for k in crop_yield:
  sum=sum+crop_yield[k]
print("sum",sum)
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# sum 265

# %% [markdown]
# j)display each crop and its yield using for loop

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
for i in crop_yield:
  print(i,crop_yield[i])
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# rice 120
# wheat 85
# maize 60

# %% [markdown]
# or

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
for i in zip (crop_yield.keys(),crop_yield.values()):
  print(i)
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# ('rice', 120)
# ('wheat', 85)
# ('maize', 60)

# %% [markdown]
# k)copy the dictionary, print the values of the new dictionary

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print("dictionary",crop_yield)
crop_yield2=crop_yield.copy()
print("crop_yield2",crop_yield2)
# Out:
# dictionary {'rice': 120, 'wheat': 85, 'maize': 60}
# crop_yield2 {'rice': 120, 'wheat': 85, 'maize': 60}

# %% [markdown]
# l)clear the elements from the new dictionary

# %%
crop_yield2.clear()
print(crop_yield2)
print(type(crop_yield2))
# Out:
# {}
# <class 'dict'>

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print(crop_yield["jower"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1922839057.py in <cell line: 0>()
#       1 crop_yield={"rice":120,"wheat":85,"maize":60}
# ----> 2 print(crop_yield["jower"])
#
# KeyError: 'jower'

# %% [markdown]
# to avoid key error use "get"

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print(crop_yield.get("jower"))
# Out:
# None

# %% [markdown]
# or

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
print(crop_yield.get("jower","not found"))
# Out:
# not found

# %% [markdown]
# pop(maize)

# %%
crop_yield={"rice":120,"wheat":85,"maize":60}
crop_yield.pop("rice")
print(crop_yield)
# Out:
# {'wheat': 85, 'maize': 60}
