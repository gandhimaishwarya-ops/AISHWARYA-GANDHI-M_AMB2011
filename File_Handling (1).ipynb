# %%
#AISHWARYA GANDHI.M
#AMB2011

# %%
file=open("GKVK.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# Hello World

# %%
file=open("GKVK.txt","w")
file.write("Hello World")
file.close()

# %% [markdown]
# **Exceptional error**

# %%
try:
  file=open("xyz.txt","r")
  content=file.read()
  print(content)
  file.close()
except:
  print("no such file")
# Out:
# no such file

# %%
try:
  with open('abc.txt','r')as f:
    line=f.read()
    print(line)

except:
  print("Error!!No such file exist")
# Out:
# Error!!No such file exist

# %%
try:
  a=10
  b=20
  c=a+b
  print(c)
except:

# %%
#write a program to the division using function
a=5
b=2
def expr(a,b):
  c=a/b
  print(c)
expr(a,b)
# Out:
# 2.5

# %%
#zero division error
a=5
b=0
def expr(a,b):
  c=a/b
  print(c)
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2160583389.py in <cell line: 0>()
#       4   c=a/b
#       5   print(c)
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-2160583389.py in expr(a, b)
#       2 b=0
#       3 def expr(a,b):
# ----> 4   c=a/b
#       5   print(c)
#       6 expr(a,b)
#
# ZeroDivisionError: division by zero

# %%
#name error
a=5
b=2
def expr(a,b):
  c=a/d
  print(c)
expr(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2763744814.py in <cell line: 0>()
#       4   c=a/d
#       5   print(c)
# ----> 6 expr(a,b)
#
# /tmp/ipython-input-2763744814.py in expr(a, b)
#       2 b=2
#       3 def expr(a,b):
# ----> 4   c=a/d
#       5   print(c)
#       6 expr(a,b)
#
# NameError: name 'd' is not defined

# %%
def expr(a,b):
    try:
           c=a/b
    except ZeroDivisionError:
           print("divided by zero")
    except NameError:
           print("variable not declared")
    except:
           print("some error occured")
    else:
           print("excecuted without errors")
           print("value of c",c)
    finally:print("End of the program")

a=5
b=2
expr(a,b)
# Out:
# excecuted without errors
# value of c 2.5
# End of the program

# %%
a=10
b=20
expr(a,b)
# Out:
# excecuted without errors
# value of c 0.5
# End of the program
